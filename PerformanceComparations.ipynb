# %%
###DATASET Y MANIPULACION

from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt


# fetch dataset
df = pd.read_csv("/content/diabetes_binary_5050split_health_indicators_BRFSS2015.csv")

! pip install fastapi
! pip install python-multipart
! pip install uvicorn
! pip install -q git+https://github.com/pycaret/pycaret.git

from pycaret.classification import *
setup_de_classificacion = setup(data=df, target='Diabetes_binary')
mejores_modelos = compare_models(n_select=5)
len(df.loc[df['Diabetes_binary'] == 0]) / len(df)
mejores_modelos[0]
type(mejores_modelos[0])
best_tunado = tune_model(mejoress_modelos[0])
modelo_final = finalize_model(best_tunado)
plot_model(modelo_final)
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# <style type="text/css">
# #T_ecba7_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ecba7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecba7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ecba7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecba7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ecba7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ecba7_row0_col1" class="data row0 col1" >1353</td>
#     </tr>
#     <tr>
#       <th id="T_ecba7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ecba7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ecba7_row1_col1" class="data row1 col1" >Diabetes_binary</td>
#     </tr>
#     <tr>
# ...

# %%
modelo_final
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['HighBP', 'HighChol', 'CholCheck',
#                                              'BMI', 'Smoker', 'Stroke',
#                                              'HeartDiseaseorAttack',
#                                              'PhysActivity', 'Fruits',
#                                              'Veggies', 'HvyAlcoholConsump',
#                                              'AnyHealthcare', 'NoDocbcCost',
#                                              'GenHlth', 'MentHlth', 'PhysHlth',
#                                              'DiffWalk', 'Sex', 'Age',
#                                              'Education', 'Income'],
#                                     tra...
#                                 boosting_type='gbdt', class_weight=None,
# ...
